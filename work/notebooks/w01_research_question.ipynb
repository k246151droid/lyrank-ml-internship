# %% [markdown]
# <a href="https://colab.research.google.com/github/k246151droid/lyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/k246151droid/lyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# Customer Retention / Churn Prediction (or your preferred lane)
# why:I selected this lane because identifying users who are about to leave allows the team to take proactive steps before revenue is lost. Predicting churn accurately directly affects recurring revenue and customer lifetime value.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# Unit of Analysis: A single client/user account.
#
# Output: A predicted risk score (0 to 1) indicating the probability of churn/cancellation within the next 30 days.
#
# Decision: Should the customer success team reach out to offer a custom incentive/discount?
#
# Action Taken: Send a targeted retain-offer email or assign a customer representative to schedule a call.
#
# Cost of Error:
#
# False Positive (Predict churn, but they stay): Wasted budget on unnecessary discounts/incentives.
#
# False Negative (Predict stay, but they churn): Total loss of the client and their recurring revenue (much higher cost).
#
# Why ML/Data Helps: Human analysis cannot track complex behavioral signals across thousands of daily active users simultaneously.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
import glob
import pandas as pd

# 1. Repo Clone
if not os.path.exists('lyrank-ml-internship'):
    # !git clone https://github.com/k246151droid/lyrank-ml-internship.git

# 2. Poori repository me koi bhi dataset (.csv ya .parquet) dhoondain
found_files = glob.glob('lyrank-ml-internship/**/*.*', recursive=True)
data_files = [f for f in found_files if f.endswith(('.csv', '.parquet', '.tsv'))]

print("Found Data Files:", data_files)

if data_files:
    target_file = data_files[0]
    print(f"\nLoading File: {target_file}")

    # Load File
    if target_file.endswith('.parquet'):
        df = pd.read_parquet(target_file)
    else:
        df = pd.read_csv(target_file)

    # Key Numbers
    print("\n--- DATA STATISTICS ---")
    print(f"Number 1 - Total Rows/Records: {len(df):,}")
    print(f"Number 2 - Total Columns: {len(df.columns)}")
    print(f"Number 3 - Total Missing Values: {df.isnull().sum().sum():,}")
else:
    print("\nNo dataset file found! Showing repository structure:")
    print(os.listdir('lyrank-ml-internship'))
# Out:
# Found Data Files: ['lyrank-ml-internship/data/raw/content_refresh_anonymized.csv', 'lyrank-ml-internship/outputs/refresh_queue_sample.csv']
#
# Loading File: lyrank-ml-internship/data/raw/content_refresh_anonymized.csv
#
# --- DATA STATISTICS ---
# Number 1 - Total Rows/Records: 30,000
# Number 2 - Total Columns: 44
# Number 3 - Total Missing Values: 73,868

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
# What I can claim: This model identifies correlated behavioral patterns that signal high churn risk.
#
# What I CANNOT claim: The model does not establish direct causation. It predicts likelihood based on historical trends, not absolute certainty.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [yes ] Every section above is filled — markdown thinking AND the code that backs it
# - [ yes] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ yes] No client names, URLs, or private queries anywhere
# - [ yes] My claims use careful words: observed, measured, directional, decision-support
# - [ yes] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
